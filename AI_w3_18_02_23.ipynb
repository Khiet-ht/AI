# %% [markdown]
# <a href="https://colab.research.google.com/github/Khiet-ht/Bai_Tap_AI/blob/main/AI_w3_18_02_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Create a dataframe

# %%
import pandas as pd
dtaframe = pd.DataFrame()
dataframe['Name']=['Lemon','Apple','Banana']
dtaframe['Price']=[8,10,12]
dataframe['License']=[False,True,True]
#show data
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      8    False
# 1   Apple     10     True
# 2  Banana     12     True

# %%
df = dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
df.loc[(df.Price ==10)]
# Out:
#     Name  Price  License
# 1  Apple     10     True

# %%
df.loc[(df.Price ==10)|(df.Name =='Banana')]
# Out:
#      Name  Price  License
# 1   Apple     10     True
# 2  Banana     12     True

# %%
df.loc[(df.Price ==8)|(df.Name =='Banana'),['Name','License']]
# Out:
#      Name  License
# 0   Lemon    False
# 2  Banana     True

# %%
df.iloc[2:3]
# Out:
#      Name  Price  License
# 2  Banana     12     True

# %%
#df.iloc[0:2,0:-1]
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
print('tong la  ',df.Price.sum())
# Out:
# tong la   30

# %%
print('max la  ',df.Price.max())
# Out:
# max la   12

# %%
print('min la  ',df.Price.min())
# Out:
# min la   8

# %%
# create row data
new = pd.Series(['Organe','15',True],index=['Name','Price','License'])
#append data row
dataframe.append(new,ignore_index=True)
# Out:
#      Name Price  License
# 0   Lemon     8    False
# 1   Apple    10     True
# 2  Banana    12     True
# 3  Organe    15     True

# %%
df = dataframe
#append a column
dataframe['Location']= ['VN','USA','TQ']
dataframe
# Out:
#      Name  Price  License Location
# 0   Lemon      8    False       VN
# 1   Apple     10     True      USA
# 2  Banana     12     True       TQ

# %%
#delete a row
df.drop(1, axis=0).head(10)   # axis=0 xoa hang
# Out:
#      Name  Price  License Location
# 0   Lemon      8    False       VN
# 2  Banana     12     True       TQ

# %%
df.drop('License',axis=1).head()    #axis=1 xoa cot
# Out:
#      Name  Price Location
# 0   Lemon      8       VN
# 1   Apple     10      USA
# 2  Banana     12       TQ

# %%
#replace 
df['Price'].replace(8,11).head(5)
# Out:
# 0    11
# 1    10
# 2    12
# Name: Price, dtype: int64

# %%
# rename columns
dataframe.rename(columns={'Price':'Cost'}).head()
# Out:
#      Name  Cost  License Location
# 0   Lemon     8    False       VN
# 1   Apple    10     True      USA
# 2  Banana    12     True       TQ

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
dataframe = pd.read_csv(url)
dataframe.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
data = dataframe
data.shape
# Out:
# (2311, 8)

# %%
data.describe()
#std : phuong sai
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
data.iloc[0:10]
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# ...

# %%
data.iloc[:200]
# Out:
#      Year        City       Sport       Discipline  NOC         Event  \
# 0    1924    Chamonix     Skating   Figure skating  AUT    individual
# 1    1924    Chamonix     Skating   Figure skating  AUT    individual
# 2    1924    Chamonix     Skating   Figure skating  AUT         pairs
# 3    1924    Chamonix   Bobsleigh        Bobsleigh  BEL      four-man
# 4    1924    Chamonix  Ice Hockey       Ice Hockey  CAN    ice hockey
# ..    ...         ...         ...              ...  ...           ...
# 195  1948  St. Moritz     Skating   Figure skating  CAN         pairs
# 196  1948  St. Moritz     Skating    Speed skating  FIN        10000m
# 197  1948  St. Moritz     Skating    Speed skating  FIN        10000m
# 198  1948  St. Moritz      Skiing  Cross Country S  FIN  4x10km relay
# 199  1948  St. Moritz      Skiing  Cross Country S  FIN          50km
#
#     Event gender   Medal
# 0              M  Silver
# 1              W    Gold
# 2              X    Gold
# ...

# %%
data.iloc[[200]]
# Out:
#      Year        City   Sport       Discipline  NOC       Event Event gender  \
# 200  1948  St. Moritz  Skiing  Nordic Combined  FIN  individual            M
#
#     Medal
# 200  Gold

# %%
data = data.set_index(data['NOC'])
data.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# ...
